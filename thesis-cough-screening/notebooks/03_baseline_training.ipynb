# %% [markdown]
# # Baseline Training
#
# Use this notebook to inspect class balance, training history, and saved checkpoints.

# %%
import pandas as pd
from pathlib import Path

train_split = Path('metadata/splits/train.csv')
if train_split.exists():
    df = pd.read_csv(train_split)
    print(df['label_multiclass'].value_counts(dropna=False))
else:
    print('Run bash scripts/run_audit.sh first.')
