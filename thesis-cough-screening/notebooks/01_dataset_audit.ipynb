# %% [markdown]
# # Dataset Audit
#
# Use this notebook to inspect raw dataset structure, audit outputs, and cleaned metadata tables.

# %%
from pathlib import Path
import json
import pandas as pd

project_root = Path.cwd().resolve().parents[0]
audit_dir = project_root / 'metadata' / 'raw'
for path in sorted(audit_dir.glob('*_audit.json')):
    print(f'\n=== {path.name} ===')
    print(json.loads(path.read_text())['audio_file_count'])
