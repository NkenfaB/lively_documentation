# %% [markdown]
# # Evaluation
#
# Use this notebook to inspect confusion matrices, classification reports, and misclassified examples.

# %%
from pathlib import Path
import pandas as pd

metrics_path = Path('reports/tables/test_metrics.csv')
if metrics_path.exists():
    display(pd.read_csv(metrics_path))
else:
    print('Run bash scripts/run_evaluation.sh after training.')
